# %%
import pandas as pd

# %%
df = pd.read_json('comments.json', orient='records')

# %%
df.rename(columns={0: 'comment'}, inplace=True)
df
# Out:
#                                               comment
# 0                          Great a regular douchebag.
# 1   My husbands favorite cake is an orange chiffon...
# 2   This looks lovely and I wish you all the stren...
# 3                          This was delicious. Thanks
# 4   Is that 180 g plus 1 Tbsp of sugar? Just tryin...
# 5   Fairly similar to what I make, but I add a gla...
# 6                                         Looks tasty
# 7                                           [removed]
# 8   Parm reggiano has to have rennet if we're goin...
# 9                        Great a selective douchebag.
# 10  Don't mind me as I drool uncontrollably into m...
# 11  **Original recipe published via Mem: https://m...
# 12  It's not an oxymoron, but it is redundant.\n\n...
# 13  Right, of course! Thank you. :) That's what I ...
# 14                                              np :)
# 15  Salaam wa alaykum fellow Moroccan. How did it ...
# ...
