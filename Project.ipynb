# %% [markdown]
# # SET UPS
#
# - installing the dependencies and packages neccessary for GPT2 (This may take ~ 1 min)
#
# - initialize environment variables

# %%
# install GPT 2 via pip command 
# !pip install --upgrade pip  # ensures that pip is current
# !pip install git+https://github.com/huggingface/transformers@main # install GPT2 and related dependencies
# !pip install git+https://github.com/google-research/bleurt # install bluert score and related dependencies

# %%
# imports
import os
import numpy as np
import pandas as pd
import random
from transformers import AutoTokenizer, AutoConfig, AutoModelForPreTraining, \
                         AdamW, get_linear_schedule_with_warmup, \
                         TrainingArguments, BeamScorer, Trainer

import torch
from torch.utils.data import Dataset, random_split, DataLoader, \
                             RandomSampler, SequentialSampler

# %%
DEBUG           = False
GPU             = False
APEX_OPT_LEVEL  = 'O1'
MODEL           = 'gpt2'

SPECIAL_TOKENS  = { "bos_token": "<|BOS|>",
                    "eos_token": "<|EOS|>",
                    "unk_token": "<|UNK|>",                    
                    "pad_token": "<|PAD|>",
                    "sep_token": "<|SEP|>"}
                    
MAXLEN          = 768 # largest possible length given colab's capacities

TRAIN_SIZE      = 0.8

TRAIN_DATA_CKPT = 0      # position of last trained data
TRAIN_DATA_LIMIT = 50 # ~ 1 - 1.5 hr training time for 10000 of data pts

TRAIN_BATCHSIZE = 4   # largest possible batCh given colab's capacities
BATCH_UPDATE    = 16

EPOCHS          = 4
LR              = 5e-4
EPS             = 1e-8
WARMUP_STEPS    = 1e2

SEED            = 1234

# %%
def SETSEED(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

SETSEED(SEED)

# %% [markdown]
# # LOAD DATA
#
# Modify the following paths according to your directory structure

# %%
# path to data file
DATA_PATH = 'sample_data.csv'

# path to model, 'None' if there is no model or you would like to train new model
MODEL_PATH = 'model.bin'

# DIRECTORY to save model in (you don't have to change this unless you want to train model)
SAVE_MODEL_DIR = ''

# DIRECTORY to save generated data in (you don't have to change this unless you want to save generated results)
SAVE_DATA_DIR = 'generated_results/'

# %%
# Mount google drive if using colab, else skip
# from google.colab import drive
# drive.mount('/content/drive')

# %%
all_data = pd.read_csv(DATA_PATH)
data = all_data[TRAIN_DATA_CKPT: TRAIN_DATA_CKPT + TRAIN_DATA_LIMIT]

# %%
class RecipeDataset(Dataset):
    def __init__(self, data, tokenizer, randomize=True):
        self.randomize = randomize
        self.tokenizer = tokenizer 
        self.ingredients = list(data['ingredients'])
        self.instructions = list(data['instructions'])

    def __len__(self):
        return len(self.ingredients)
    
    def __getitem__(self, i):
        
        input = SPECIAL_TOKENS['bos_token'] + self.ingredients[i] + SPECIAL_TOKENS['sep_token'] + \
                self.instructions[i] + SPECIAL_TOKENS['eos_token']

        encodings_dict = self.tokenizer(input,                                   
                                   truncation=True, 
                                   max_length=MAXLEN, 
                                   padding="max_length")   
        
        input_ids = encodings_dict['input_ids']
        attention_mask = encodings_dict['attention_mask']
        
        return {'label': torch.tensor(input_ids),
                'input_ids': torch.tensor(input_ids), 
                'attention_mask': torch.tensor(attention_mask)}

# %%
def get_tokenier(special_tokens):
    tokenizer = AutoTokenizer.from_pretrained(MODEL)  
    tokenizer.add_special_tokens(special_tokens)
    return tokenizer

def get_model(tokenizer, special_tokens, load_model_path=None):

    
    config = AutoConfig.from_pretrained(MODEL, 
                                        bos_token_id=tokenizer.bos_token_id,
                                        eos_token_id=tokenizer.eos_token_id,
                                        sep_token_id=tokenizer.sep_token_id,
                                        pad_token_id=tokenizer.pad_token_id,
                                        output_hidden_states=False)
   

    model = AutoModelForPreTraining.from_pretrained(MODEL, config=config)
    model.resize_token_embeddings(len(tokenizer))

    if load_model_path:
        model.load_state_dict(torch.load(load_model_path,map_location=torch.device('cpu')))
    if GPU:
        model.cuda()
    return model

# %% [markdown]
# # Model Loading

# %%
tokenizer = get_tokenier(SPECIAL_TOKENS)
model = get_model(tokenizer, 
                  SPECIAL_TOKENS,
                  load_model_path= MODEL_PATH
                  )

# %% [markdown]
# # Model Training

# %%
train_data = data.iloc[0:int(len(data)*TRAIN_SIZE), :]
val_data = data.iloc[int(len(data)*TRAIN_SIZE):, :]

train_dataset = RecipeDataset(train_data, tokenizer)
val_dataset = RecipeDataset(val_data, tokenizer, randomize=False)

f'TRAINING SMAPLES: {len(train_dataset) :,} || TESTING SAMPLES: {len(val_dataset) :,}'
# Out:
# 'TRAINING SMAPLES: 40 || TESTING SAMPLES: 10'

# %%
torch.cuda.empty_cache()
training_args = TrainingArguments(
    output_dir="/content/",
    num_train_epochs=EPOCHS,
    per_device_train_batch_size=TRAIN_BATCHSIZE,
    per_device_eval_batch_size=TRAIN_BATCHSIZE,
    gradient_accumulation_steps=BATCH_UPDATE,
    evaluation_strategy="epoch",
    fp16=True,
    fp16_opt_level=APEX_OPT_LEVEL,
    warmup_steps=WARMUP_STEPS,    
    learning_rate=LR,
    adam_epsilon=EPS,
    weight_decay=0.01,        
    save_total_limit=1
)

trainer = Trainer(
    model=model,
    args=training_args,    
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer
)

trainer.train()
trainer.save_model()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22524\4078368144.py in <module>
#      13     adam_epsilon=EPS,
#      14     weight_decay=0.01,
# ---> 15     save_total_limit=1
#      16 )
#      17
#
# c:\users\fuyus\appdata\local\programs\python\python37\lib\site-packages\transformers\training_args.py in __init__(self, output_dir, overwrite_output_dir, do_train, do_eval, do_predict, evaluation_strategy, prediction_loss_only, per_device_train_batch_size, per_device_eval_batch_size, per_gpu_train_batch_size, per_gpu_eval_batch_size, gradient_accumulation_steps, eval_accumulation_steps, eval_delay, learning_rate, weight_decay, adam_beta1, adam_beta2, adam_epsilon, max_grad_norm, num_train_epochs, max_steps, lr_scheduler_type, warmup_ratio, warmup_steps, log_level, log_level_replica, log_on_each_node, logging_dir, logging_strategy, logging_first_step, logging_steps, logging_nan_inf_filter, save_strategy, save_steps, save_total_limit, save_on_each_node, no_cuda, seed, data_seed, bf16, fp16, fp16_opt_level, half_precision_backend, bf16_full_eval, fp16_full_eval, tf32, local_rank, xpu_backend, tpu_num_cores, tpu_metrics_debug, debug, dataloader_drop_last, eval_steps, dataloader_num_workers, past_index, run_name, disable_tqdm, remove_unused_columns, label_names, load_best_model_at_end, metric_for_best_model, greater_is_better, ignore_data_skip, sharded_ddp, deepspeed, label_smoothing_factor, optim, adafactor, group_by_length, length_column_name, report_to, ddp_find_unused_parameters, ddp_bucket_cap_mb, dataloader_pin_memory, skip_memory_metrics, use_legacy_prediction_loop, push_to_hub, resume_from_checkpoint, hub_model_id, hub_strategy, hub_token, gradient_checkpointing, fp16_backend, push_to_hub_model_id, push_to_hub_organization, push_to_hub_token, mp_parameters)
#
# c:\users\fuyus\appdata\local\programs\python\python37\lib\site-packages\transformers\training_args.py in __post_init__(self)
#     868         ):
#     869             raise ValueError(
# --> 870                 "Mixed precision training with AMP or APEX (`--fp16` or `--bf16`) and half precision evaluation (`--fp16_full_eval` or `--bf16_full_eval`) can only be used on CUDA devices."
#     871             )
#     872
#
# ValueError: Mixed precision training with AMP or APEX (`--fp16` or `--bf16`) and half precision evaluation (`--fp16_full_eval` or `--bf16_full_eval`) can only be used on CUDA devices.

# %% [markdown]
# # Model Saving

# %%
MODEL_NAME = 'TEST-model.bin'
path = SAVE_MODEL_DIR + MODEL_NAME
torch.save(model.state_dict(), path)

# %% [markdown]
# # Generation

# %%
#ingredient = list(data['ingredients'])[0]
ingredient = "Ingredients: 1. 2 pound of beef 2. 1 cup of water 3. 1 cup of coffee 4. 1 cup of cream 5. 1 tablespoon of salt 6. 2 tablespoon of sugar 7. 2 cup of cheese 8. 1 onion 9. 1 cup of flour"

prompt = SPECIAL_TOKENS['bos_token']  + ingredient + SPECIAL_TOKENS['sep_token']
         
generated = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)
device = torch.device("cuda")
#generated = generated.to(device)

model.eval();

# %% [markdown]
# ### Optimal Temperature: Best Results

# %%
sample_outputs = model.generate(generated, 
                                do_sample=True,   
                                min_length=50, 
                                max_length=MAXLEN,
                                top_k=30,                                 
                                top_p=0.7,        
                                temperature=1.5,
                                repetition_penalty=1.0,
                                num_return_sequences=10
                                )

# %%
for i, sample_output in enumerate(sample_outputs):
    text = tokenizer.decode(sample_output, skip_special_tokens=True)
    if i == 0:
      print(text.split('Instructions:')[0], '\n', '-'*10, '\n', sep = '')
    print('Instructions:', text.split('Instructions:')[1], '\n', sep = '')
# Out:
# Ingredients: 1. 2 pound of beef 2. 1 cup of water 3. 1 cup of coffee 4. 1 cup of cream 5. 1 tablespoon of salt 6. 2 tablespoon of sugar 7. 2 cup of cheese 8. 1 onion 9. 1 cup of flour
# ----------
#
# Instructions: 1. Put the flour in a bowl. 2. Put in the beef broth and water. 3. Mix with a fork. 4. Let stand until thickened. 5. Drain and mix with the cream. 6. Blend with electric mixer. 7. Add the salt, sugar, pepper, cheese and onion. 8. Add some flour to make the mixture a bit smooth and add to the filling. 9. Mix well. 10. Mix well and place in a buttered baking dish. 11. Bake in a 375 degree oven for 45 to 60 minutes.
#
# Instructions: 1. Combine beef, water, 1 cup coffee, cream, salt and sugar. 2. Mix well. 3. Add grated cheese, onions and flour, and stir until blended. 4. Cook in hot iron skillet or skillet. 5. Top with sauce and bake for 20 to 25 minutes at 350 degrees.
#
# Instructions: 1. Brown the ground beef and add the water and coffee. 2. Simmer the beef for 30 minutes, adding water if needed. 3. Add the cream and salt, sugar, and sugar. 4. Cook for 5 minutes more, then add the grated cheese. 5. Cook another 5 minutes until cheese melts. 6. Add the flour and cook for another minute. 7. Remove from the heat and stir in the cream. 8. Let stand for 2 minutes. 9. Roll into bite size patties. 10. Broil on high until they turn golden.
#
# Instructions: 1. Mix all ingrediants except flour, put on a plate and put in oven at 325 degrees until done. 2. In 9x13 baking pan, pour flour over top of meat. 3. Mix 1 cup of cheese with 1 cup of water and pour on top of flour. 4. Mix all ingredients, except flour, add to meat in baking pan and bake at 350 degrees for 30 to 40 min, or until done. 5. Let stand 5 to 10 min to let the cheese soak in.
#
# Instructions: 1. Mix the beef, water, coffee, cream, salt and sugar together in a saucepan. 2. Bring to a boil, then reduce the heat and simmer for 15 minutes. 3. Remove the meat, add cheese and onion. 4. Blend the flour with a hand beater until smooth and add to the stew. 5. Cook, covered, for about an hour and 20 minutes until the beef is tender and all the liquid has cooked out. 6. If you like the taste more, boil away the fat and pour into a sauceboat. 7. You will be surprised how fast this dish can be made!
#
# Instructions: 1. 1. 2. In a pot brown ground beef with water. 3. Add water and beans. 4. Bring to a boil and let boil for 2 minutes. 5. 2. 6. Add cheese, onions and flour. 7. 3. 8. Stir to blend, and pour into a 2 quart baking dish. 9. 4. 10. Let cool and chill for 3 days, turning the dish every so often. 11. Then serve with cornbread sticks and green beans or biscuits.
#
# Instructions: 1. Cook beef, onion and garlic together. 2. Remove meat to a bowl and add remaining ingredients except flour and coffee and cream and let cool. 3. Form mixture into 1" meatballs. 4. Cook slowly for 1 hour. 5. Sprinkle with flour and add a little more coffee or milk to make gravy. 6. Bake at 325F for 40 to 45 minutes until cooked thoroughly. 7. Remove meatballs from the oven and serve.
#
# Instructions: 1. Mix the water, coffee, cream, salt and sugar. 2. Mix well. 3. Add the meat. 4. Put the mix into a loaf pan. 5. Add 1 cup of cheese, add sliced onions and sliced cheese. 6. Put into the freezer for 1 hour. 7. Put in the oven. 8. Bake at 350 degrees for 1 1/2 hours. 9. When the loaf is frozen, it is ready to serve.
#
# Instructions: 1. Mix together and shape into meatballs. 2. Add in water and coffee and cook for an hour. 3. Add in the cream, salt, sugar and onions. 4. Cook slowly for 15 minutes. 5. Add in the cheese. 6. Cook until browned.
#
# Instructions: 1. Brown the meat slowly, and drain off any excess fat. 2. Mix with the water, cream, salt, sugar, and cheese. 3. Cook slowly, and stir in the flour gradually. 4. Cook for 5 to 10 minutes. 5. This recipe can be made up to 2 weeks in advance, covered. 6. Put the ingredients for the sauce in the freezer compartment of a slow cooker. 7. Fill the sauce with meat mixture, cover, and put the lid on. 8. Set on low for 8 to 10 hours, or high for 5 to 10 hours. 9. The mixture can be used immediately after the stove comes to low setting.

# %% [markdown]
# ### Low Temperature: High Bias
#
# All the generated results will look very similar to each other if not completely identical

# %%
sample_outputs = model.generate(generated, 
                                do_sample=True,   
                                min_length=50, 
                                max_length=MAXLEN,
                                top_k=30,                                 
                                top_p=0.7,        
                                temperature=0.1,
                                repetition_penalty=1.0,
                                num_return_sequences=10
                                )
for i, sample_output in enumerate(sample_outputs):
    text = tokenizer.decode(sample_output, skip_special_tokens=True)
    if i == 0:
      print(text.split('Instructions:')[0], '\n', '-'*10, '\n', sep = '')
    print('Instructions:', text.split('Instructions:')[1], '\n', sep = '')
# Out:
# Ingredients: 1. 2 pound of beef 2. 1 cup of water 3. 1 cup of coffee 4. 1 cup of cream 5. 1 tablespoon of salt 6. 2 tablespoon of sugar 7. 2 cup of cheese 8. 1 onion 9. 1 cup of flour
# ----------
#
# Instructions: 1. Brown the ground beef in a skillet. 2. Add the water, coffee, cream, salt, sugar, and cheese. 3. Simmer for 20 minutes. 4. Add the onion and cook for another 10 minutes. 5. Add the flour and cook for 5 minutes. 6. Serve with mashed potatoes.
#
# Instructions: 1. Brown the ground beef in a skillet. 2. Add the water, coffee, cream, salt, sugar, and cheese. 3. Simmer for 20 minutes. 4. Add the onion and cook for another 10 minutes. 5. Add the flour and cook for another 10 minutes. 6. Serve with mashed potatoes.
#
# Instructions: 1. Brown the ground beef in a skillet. 2. Add the water, coffee, cream, salt, sugar, and cheese. 3. Simmer for 20 minutes. 4. Add the onion and cook for another 10 minutes. 5. Add the flour and cook for 5 minutes. 6. Serve with mashed potatoes.
#
# Instructions: 1. Brown the ground beef in a skillet. 2. Add the water, coffee, cream, salt, sugar, and cheese. 3. Simmer for 20 minutes. 4. Add the onion and cook for another 10 minutes. 5. Add the flour and cook for 5 minutes. 6. Serve with mashed potatoes.
#
# Instructions: 1. Brown the ground beef in a skillet. 2. Add the water, coffee, cream, salt, sugar, and cheese. 3. Simmer for 20 minutes. 4. Add the onion and cook for another 10 minutes. 5. Add the flour and cook for 5 minutes. 6. Serve with mashed potatoes.
#
# Instructions: 1. Brown the ground beef in a skillet. 2. Add the water, coffee, cream, salt, sugar, and cheese. 3. Simmer for 20 minutes. 4. Add the onion and cook for another 10 minutes. 5. Add the flour and cook for another 5 minutes. 6. Serve with mashed potatoes.
#
# Instructions: 1. Brown the ground beef in a skillet. 2. Add the water, coffee, cream, salt, sugar, and cheese. 3. Simmer for 20 minutes. 4. Add the onion and cook for another 10 minutes. 5. Add the flour and cook for 5 minutes. 6. Serve with mashed potatoes.
#
# Instructions: 1. Brown the ground beef in a skillet. 2. Add the water, coffee, cream, salt, sugar, and cheese. 3. Simmer for 20 minutes. 4. Add the onion and cook for another 10 minutes. 5. Add the flour and cook for another 10 minutes. 6. Serve with mashed potatoes.
#
# Instructions: 1. Brown the ground beef in a skillet. 2. Add the water, coffee, cream, salt, sugar, and cheese. 3. Simmer for 20 minutes. 4. Add the onion and cook for another 10 minutes. 5. Add the flour and cook for 5 minutes. 6. Serve with mashed potatoes.
#
# Instructions: 1. Brown the ground beef in a skillet. 2. Add the water, coffee, cream, salt, sugar, and cheese. 3. Simmer for 20 minutes. 4. Add the onion and cook for another 10 minutes. 5. Add the flour and cook for 5 minutes. 6. Serve with mashed potatoes.

# %% [markdown]
# ### High Temperature: High Variance
#
# starts to use ingreidents out side of input; loses structure
#
# emm... Don't try this at home

# %%
sample_outputs = model.generate(generated, 
                                do_sample=True,   
                                min_length=50, 
                                max_length=MAXLEN,
                                top_k=30,                                 
                                top_p=0.7,        
                                temperature=2.0,
                                repetition_penalty=1.0,
                                num_return_sequences=10
                                )
for i, sample_output in enumerate(sample_outputs):
    text = tokenizer.decode(sample_output, skip_special_tokens=True)
    if i == 0:
      print(text.split('Instructions:')[0], '\n', '-'*10, '\n', sep = '')
    print('Instructions:', text.split('Instructions:')[1], '\n', sep = '')
# Out:
# Ingredients: 1. 2 pound of beef 2. 1 cup of water 3. 1 cup of coffee 4. 1 cup of cream 5. 1 tablespoon of salt 6. 2 tablespoon of sugar 7. 2 cup of cheese 8. 1 onion 9. 1 cup of flour
# ----------
#
# Instructions: 1. Combine first 6 ingredients. 2. Roll meat in flour, brown. 3. Remove and repeat. 4. Pour boiling water over all, mix well, and simmer 15 minute Put on wax paper or wax paper lined baking sheet, and freeze 1 to 1 1/2 months.
#
# Instructions: 1. Put beef and water in crock pot 2. Mix sugar, salt, sugar and cornstarch in bowl. 3. Add beef mixture and stir until smooth. 4. Layer crockpot with cheese layer, beef mix with onion and then with flour mixture in same manner. 5. Cook for 6 hours on Low. 6. Stir before serving, top with additional grated cheese.
#
# Instructions: 1. Brown hamburger in butter. 2. Stir in water. 3. Simmer till the sauce thickens. 4. Then add coffee. 5. Combine salt and 1 T sugar, bring to boil then stir into thickening sauce, stir in onions. 6. Put a thin layer of flour in each cup to hold shape, then cover with cheese and hamburger mixture to make a top for gravy later.
#
sample_outputs = model.generate(generated, 
                                do_sample=True,   
                                min_length=50, 
                                max_length=MAXLEN,
                                top_k=30,                                 
                                top_p=0.7,        
                                temperature=10.0,
                                repetition_penalty=1.0,
                                num_return_sequences=10
                                )
for i, sample_output in enumerate(sample_outputs):
    text = tokenizer.decode(sample_output, skip_special_tokens=True)
    if i == 0:
      print(ingredient, '\n', '-'*10, '\n', sep = '')
    print(text[len(ingredient):], '\n')
# Out:
# Ingredients: 1. 2 pound of beef 2. 1 cup of water 3. 1 cup of coffee 4. 1 cup of cream 5. 1 tablespoon of salt 6. 2 tablespoon of sugar 7. 2 cup of cheese 8. 1 onion 9. 1 cup of flour
# ----------
#
#  salt water dred the beef 9 pound flour salt all 10 urchkins roll up and tie the roast 12 slices day rolling 12 slices cheese and onions roll 1 egg white and 1 slice each fresh the chowder beef or turkey 9 pounds all season the rolls season flour seal seal well cut butter 10 1 cup oil deep the can fill 3x5 3 quart line fill center and rim 1 or 2 3/50 inch full make cup the pan fill holes 2 fill center and add fill 2 cover  cover oil 2 to 350 utes 9 or 12 hours if not serving over meat heat deep 12 1 x 25 cup flour dred ds water 15 x 12 rolls bread ices pre make bread holes 2 fill tops add fill the meatballs fill out the chuggets wrap cheese cut rolls slice iced in a deep hot pot to the center hole make cup and top fill them place slices put water over filling add some butter seal lid seal lid cover pot and bake on 275 to 400 or untin middle untout brown at middle turn oven side way heat butter and drippings over all fill pan add egg, sugar urchkins take small piece for cheese add meat on chips sprinkle some dry parsher and place pieces of egg yummy on flour tb holes. 7 or just any leftovers cook 20 minutes. check for meat if serving ichips may dry off top may not be served in the refrigerator to bake
#
#  9 inch cornstarch thins cereal rips heavy biscuits with poupin baking pam machine and cut squares from biscuits dough out or cut into biscure form or form as needed, about 15 inch slices  1 2 pound  beef rind 2 3 inch thick rounds; brown griss-toote and sprinkle wencks well in warm grease and keep aside 9 inches pastry, thumped together the flour dredges well on all surfaces. 15 to 25 pieces  Roll up one corner, and pleases nicely.Take off wax or papster paper and grease bottom grate or grills, leaving 2 small patter at bottom;place filling, 1 short length sides inward ;turn carefully under pressure to coat lightly in the fat or the butter mix 11 1 or 16 times in the first, leaving 1 in left edge 12 to 18 as possible 17 inch opening for the second and 9 in middle positions or 18 - 18 slices overhang filling at top center;turn, bakinet fashion.Remove bread from grill.of grease with rolling stick,sting lightly under steam,pile in 2 Tbsp flour and 2 Cn water mixing gently into well and arrange half slices under top;pile over second long end, and pinch over the edge so which some edge sticks away at side.Beat until ready To grill. 18. Cut corn bread or dough slabs with serrated edge making small slices to your satisfaction,.then roll and cut slices on toasted side till almost covered by bread/water-wrap in cling film,pierce or twist a pastry string to open packet.with scissors if required to open ;in the same container the next morning,cover;let dry at room* 24 to36 or possibly 15 Min's for 10 minute,and let stand a half- Day before Preh while you do this as required by instructions - On greased grid over coamer - if grillin roodlough,diameter 2"-16".peanut butter cups -- 9/13 - 18  For every 1 lb., place beef ridge onto 2 greasted sheets pan,bone on 2;top 1 1 pice on second ;let stand in pan an additional 25 or possibly till you wilt 18 min. 19. To fry meat,place on a large preHEASY-GREGATE or SCUF, plastic  frying surface -- 1 2oz,1" thick on bottom" or 5 - 20 inches from very very near edge of steer  ;roll,segment with fork - 1 lb.,turn once.then make sure that bottom or middle slices is slightly moist & but a freey coating;remove from heat, & secure tightlywith a cou
#  16 18 teaspoon pap pie spice ix flour 10 21 cup white chips 23 24 10 drops of green dye orate 24 1.1 bags miniature Mop mopes with m&pes mixed in 25 tips ers 26. 1 1 cup brown chips 27 liquid 8 inch graingers with fruit sticks, crotted entsrue butter crack sticks, and cinnamon urch ips and spice crotons can yield a lot. 8 cupfuls may get messy -- or you do well and will often end up with them flat. 17 18  and no stickiness in them at Allston Farm.'s homemade coffee ice crequers can also give it additional flavor if a viewer isn',ttooto you didn't know?!' 20 To assemble sandwiches use a deep metal plate, but remember they are a really special cake. My family does and loves bears in ours, the old guard made by our dog was just good but I can also say I don' need it. 22 The butcher had already replaced it; we need just a touch left at this stage; it still works fine as always with homemade steaks on sandwiches. 'Taco' or any creaming sandwich that you make - go around eating it just a few people. 'Top your favorite items by pouring one side out on cheese of another can of Mops. 27 and the same way with any crecvre frosty sandwich, place about four small individual or four Mop pods inside a sandwich - make another one. 28 29' top the moped bits, mosepicks and driy cheese together and roll or pull the bottom of half roll closed. 29' wrap like candy corn by wrapping both side; remove when it's done with all other M Oaters!* and the end by inserting tooth spumbs under and off each Moom or Cheese. or place the other two "side up - fold top, open ends together, open. 15  and secure 'wads to touch' in pan using the waxpats; then roll the Mopa together or press it in to get some shape.Tacom is actually an immersion dixie or creami so the Mox will melt quickly but thats really what i will take until ready to serve ; 30. also can substitute pared green zing. 21. My children can usually buy some at farmers store and run in water for $25 a bottle! 22 miracle beaters  with cannel, spice crumble or spice mix or chop the amount that they would find was better - these ones will last the first night they take for the bottle & they can double ; or some smaller packages can probably do better - also buy an 8 quart pan to put 'another scoop into, open, open.and go in a picnic if it doesn., also, I've made a pretty batch - and now I just let folks cut up how else they liked them when my kid met her in Texas in eighth to learn them were actually made -- excellent coffee crack butter urchased to prevent string problems if possible-use just a knife as your guide when selecting' tools: food dehydric plate-a can hold two different things: water, hot/unsweetend/hot/low moisture items. 3 c, dehydrated or oil ; a little cinnamon for those in touch & a few fresh apples to toss it in the frost. 4 5 - mix a bunch  of dry fruits if they've aged awhile or have been pressed lightly with cinnamon-rub, some water and a few T's
#
# Instructional Time : 2 minutes or so.In order I feed people:1: Add your diced ground or canned or sliced or canned  hambood. 2 pairs: ground and shredded beef - thin.Spread meat/cheese on each plate with the bottom part.then top the burger  using 2 slices at once.Spread with any condiment left over in sauce cup.I also recommend an aluminum cake tumbleneck to make rolling it around this time of putting the meat "flattient".Take one onion and slice a cup thin.And that little thinly and fry until it gives the bread an extra colorand look awesome with this step to step.Using the sides only work a pretty much until the sides do feel slightly weak to press.Turn your burger out in the cake  placing each portion so they will lay flat  Do this with other sliced slices and also place it next and third slice as final assembly, lay side-down nextto the meat and add two cheesees.then put in at each sandwich spot on top or you put a sandwich together on each cookie rack that runs over end-finest ;you don't want to eat one with each "lick ".I use some paper nap roll pans in that cases.Enjoy this meal or its really tasty and serves over hot biscuits for adults only as long, does work.You want these nice, soft appetizers on their last and will still fall down with them -- Enjoy with toast points, if thats too stiff  you just toss flour into them before using your eggs, but if you use yrexin it wont cook,so make sure it isn't touching : 2 - It doesnt get quite that way and wont keep its lovely but kinda hard on one edge to hold shape in your bread -- "I eat when all is ready ".Do it to have that awesome* smell on both bottom  and both bottom as a mouth-set aside :.then keep at a cool-down place  - I used 3 and 10 lbs, both larger or smaller ; I do the heavy lifting by about 45- 60 " in long, then lift my eggs up quickly, making two long and thin, " Lift and move on cutting with "hand ".You do need something bigger for slicing - you just don't want it any size in your whole family, they do hold a shine  if its cold in my book and there ever is that faint spot you can make my sandwiches on a flat baking tin with butter and all those good qualities to all these purposes :.Shown these same night or in a pretty good store, in case they fail- :, : in order the hambo: add the following, stirring frequently to get your mixture into pebTHIN  flour: stir only until its the bottom is evenly seasoned, the larger the longer; mix in, as this is only the slightest flacculent.Take 2 of 1" sliced, finely crumled bread - spread about 2" on the inside with butter - it needs only occasional stir.Next slice a few, one thick slice -- cut 2 more or you want that extra "plain" bread  about to get "dressed", as the middle has a "tin and you won ;".  - add that slices 1 thinner one and half "large", a small slice a whole; do you still do a big part for your other sandwich!Mold out, wrap individually.of course I would be doing one in your hand with plastic as best I haVE a good piece!of
#
#  1 can 15 10 11 tablespoons oil salt 8 9x 9x 9 baking sheet entsarch
#
# 1 eggs 12 teaspoon vanilla 9 eggs yitol dissolved 11 1 12 inch ix 8 cup cream cheese sift confeder cream butter melted butter its french Buttercream 13:. 9 slices eggnaro 14 1 1.6 box corn bread crumpled 20 pound sardines 10 minute 16th rolls warm entswipe damp clean towels ----------------. 17 millilitrate flour 1 teaspoons dry sesame seeds dry cream and sugar add the melted mixture a tsp vanilla to a cup mix corn meal 1 tsp confection salt 18. add salt, butterflied vegetables and flour mixing till you can form them but do a minimum use more cornstainer and silding, mix is fine use enough corn staining if you use more corn flour 20 cp heavy milk whisk the beef. when fully incorporate incorporate let boil  add milk cook on top add coffee keep hot for 15 min and stir and heat and remove. 31/remove any vegtir the mixture drippings need water. 12 1 eggs for frost or butter the eggs with one cup softened whip all together adding enough crema not more than 1 c sugar until stiff.on wax.or s tissue the mixture is ready roll to put but still spread a little butter between the two.do little to seal it then with pastry spatio wrap in parchment form for hanging or foil place over greasing and bake
#
#  6 biscuits or round pie pan 11 x 2 inch square or 1 3 8 3 9 3inch baked 11 inch tart baking

# %% [markdown]
# # Evaluation

# %%
SAVE_DATA_FILE_NAME = 'validation_data.csv'
test_data = all_data[:10] 
validation_df = pd.DataFrame(columns = ["truth", "prediction"])
TEMPERATURE = 1.5

# %%
for i, row in test_data.iterrows():

  prompt = SPECIAL_TOKENS['bos_token']  + row["ingredients"] + SPECIAL_TOKENS['sep_token']
        
  generated = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)
  device = torch.device("cuda")
  generated = generated.to(device)

  model.eval()
  sample_outputs = model.generate(generated, 
                                do_sample=True,   
                                min_length=50, 
                                max_length=MAXLEN,
                                top_k=30,                                 
                                top_p=0.7,        
                                temperature=TEMPERATURE,
                                repetition_penalty=1.0,
                                num_return_sequences=3)
  for i, sample_output in enumerate(sample_outputs):
    text = tokenizer.decode(sample_output, skip_special_tokens=True)
    text = text.split("Instructions:")[1]
    #print(text)
    validation_df = validation_df.append({
        'truth' : row["instructions"],
        'prediction': "Instructions:" + text
    }, ignore_index=True)

#validation_df.to_csv(SAVE_DATA_DIR + SAVE_DATA_FILE_NAME)

# %%
from bleurt import score

references = validation_df['truth']
candidates = validation_df['prediction']

scorer = score.BleurtScorer()
scores = scorer.score(references=references, candidates=candidates)
# Out:
# INFO:tensorflow:No checkpoint specified, defaulting to BLEURT-tiny.
# INFO:tensorflow:Reading checkpoint /usr/local/lib/python3.7/dist-packages/bleurt/test_checkpoint.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Will load checkpoint dbleurt_tiny
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:... name:dbleurt_tiny
# INFO:tensorflow:... vocab_file:vocab.txt
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... do_lower_case:True
# INFO:tensorflow:... max_seq_length:512
# INFO:tensorflow:Creating BLEURT scorer.
# INFO:tensorflow:Creating WordPiece tokenizer.
# INFO:tensorflow:WordPiece tokenizer instantiated.
# INFO:tensorflow:Creating Eager Mode predictor.
# INFO:tensorflow:Loading model.
# INFO:tensorflow:BLEURT initialized.

# %%
pd.DataFrame(scores).describe()
# Out:
#                0
# count  30.000000
# mean   -0.453432
# std     0.288420
# min    -1.071038
# 25%    -0.604296
# 50%    -0.395737
# 75%    -0.296551
# max     0.094377
